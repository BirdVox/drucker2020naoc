# %%
import birdvoxpaint as bvp
import librosa
import os

# %%
wav_path = os.path.join(
    "/Users", "vl238", "Box Sync",
    "BOGOTA_NFCs_2018", "MonserrateNFCs",
    "SWIFT_20181106_235545.wav")

X = bvp.transform(
        wav_path,
        indices=[bvp.acoustic_complexity_index, bvp.entropy_based_concentration, bvp.acoustic_event_count])

bvp.rgbshow(X)
# Out:
# 20it [00:05,  3.77it/s]

# %%
wav_path = '/Users/vl238/Box Sync/BOGOTA_NFCs_2018/MonserrateNFCs/SWIFT_20181106_235545.wav'
# Out:
# '/Users/vl238/Box Sync/BOGOTA_NFCs_2018/MonserrateNFCs/SWIFT_20181106_235545.wav'

# %%
X = bvp.transform(
    wav_path,
    indices=[
        bvp.acoustic_complexity_index,
        bvp.entropy_based_concentration,
        bvp.acoustic_event_count,
    ],
)

# %%
import os
y, sr = librosa.load("/Users/vl238/librosa/librosa/util/example_data/Kevin_MacLeod_-_Vibe_Ace.ogg")
# Out:
# /Users/vl238/librosa/librosa/core/audio.py:143: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn('PySoundFile failed. Trying audioread instead.')

# %%
y.shape
# Out:
# (1355168,)

# %%
filename = librosa.util.example_audio_file()
sr = librosa.get_samplerate(filename)
stream = librosa.stream(filename,
                      block_length=256,
                      frame_length=4096,
                      hop_length=1024)
for y_block in stream:
    D_block = librosa.stft(y_block, center=False)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-10-c7041dc26373> in <module>
#       5                       frame_length=4096,
#       6                       hop_length=1024)
# ----> 7 for y_block in stream:
#       8     D_block = librosa.stft(y_block, center=False)
#
# ~/librosa/librosa/core/audio.py in stream(path, block_length, frame_length, hop_length, mono, offset, duration, fill_value, dtype)
#     356
#     357     # Get the sample rate from the file info
# --> 358     sr = sf.info(path).samplerate
#     359
#     360     # If the input is a file handle, rewind its read position after `sf.info`
#
# ~/miniconda3/lib/python3.7/site-packages/soundfile.py in info(file, verbose)
#     550         Whether to print additional information.
#     551     """
# --> 552     return _SoundFileInfo(file, verbose)
#     553
#     554
#
# ...
